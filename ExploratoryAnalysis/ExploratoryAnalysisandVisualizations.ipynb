# %%
# Title:     SmartHome Dataset
# Authors:   Aline J
# Date:      01/06/2020
# Goal:      Analyze and predict energy use efficiency 
#            in a smarthouse during a year under variable weather conditions.
# Questions: 
# 1) What are the variables that influence energy efficiency? 
# 2) When is 
### Begins Here ####
# 1. Import dependencies
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from scipy import stats
import string as string
import warnings
warnings.filterwarnings('ignore')
#from learntools.core import binder
#binder.bind(globals())
#from learntools.data_viz_to_coder.ex7 import *
#print("Setup Complete")

# %%
# 2. Import Raw data file into a data frame
csv_path = "Data/HomeC.csv"
my_data = pd.read_csv(csv_path,   parse_dates=True)
home_dat = my_data.select_dtypes(exclude=['object'])

#df = pd.read_csv(csv_path, delimiter=',')
#df1.dataframeName =df
#nRow, nCol = df.shape
nRow, nCol = my_data.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 503911 rows and 32 columns

# %%
time_index = pd.date_range('2016-01-01 05:00', periods=503911,  freq='min')  
time_index = pd.DatetimeIndex(time_index)
home_dat = home_dat.set_index(time_index)
# Check that a dataset has been uploaded into my_data

# %%
home_dat.head(5)
# Out:
#                      use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 2016-01-01 05:00:00  0.932833  0.003483            0.932833         0.000033
# 2016-01-01 05:01:00  0.934333  0.003467            0.934333         0.000000
# 2016-01-01 05:02:00  0.931817  0.003467            0.931817         0.000017
# 2016-01-01 05:03:00  1.022050  0.003483            1.022050         0.000017
# 2016-01-01 05:04:00  1.139400  0.003467            1.139400         0.000133
#
#                      Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  \
# 2016-01-01 05:00:00        0.020700        0.061917          0.442633
# 2016-01-01 05:01:00        0.020717        0.063817          0.444067
# 2016-01-01 05:02:00        0.020700        0.062317          0.446067
# 2016-01-01 05:03:00        0.106900        0.068517          0.446583
# 2016-01-01 05:04:00        0.236933        0.063983          0.446533
#
#                      Fridge [kW]  Wine cellar [kW]  Garage door [kW]  ...  \
# 2016-01-01 05:00:00     0.124150          0.006983          0.013083  ...
# 2016-01-01 05:01:00     0.124000          0.006983          0.013117  ...
# 2016-01-01 05:02:00     0.123533          0.006983          0.013083  ...
# 2016-01-01 05:03:00     0.123133          0.006983          0.013000  ...
# 2016-01-01 05:04:00     0.122850          0.006850          0.012783  ...
#
#                      temperature  humidity  visibility  apparentTemperature  \
# 2016-01-01 05:00:00        36.14      0.62        10.0                29.26
# 2016-01-01 05:01:00        36.14      0.62        10.0                29.26
# 2016-01-01 05:02:00        36.14      0.62        10.0                29.26
# 2016-01-01 05:03:00        36.14      0.62        10.0                29.26
# 2016-01-01 05:04:00        36.14      0.62        10.0                29.26
#
#                      pressure  windSpeed  windBearing  precipIntensity  \
# 2016-01-01 05:00:00   1016.91       9.18        282.0              0.0
# 2016-01-01 05:01:00   1016.91       9.18        282.0              0.0
# 2016-01-01 05:02:00   1016.91       9.18        282.0              0.0
# 2016-01-01 05:03:00   1016.91       9.18        282.0              0.0
# 2016-01-01 05:04:00   1016.91       9.18        282.0              0.0
#
#                      dewPoint  precipProbability
# 2016-01-01 05:00:00      24.4                0.0
# 2016-01-01 05:01:00      24.4                0.0
# 2016-01-01 05:02:00      24.4                0.0
# 2016-01-01 05:03:00      24.4                0.0
# 2016-01-01 05:04:00      24.4                0.0
#
# [5 rows x 28 columns]

# %%
my_data = home_dat[0:-1] ## == dataset[0:dataset.shape[0]-1] == dataset[0:len(dataset)-1] == dataset[:-1]
my_data.tail()
# Out:
#                      use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 2016-12-16 03:25:00  1.601233  0.003183            1.601233         0.000050
# 2016-12-16 03:26:00  1.599333  0.003233            1.599333         0.000050
# 2016-12-16 03:27:00  1.924267  0.003217            1.924267         0.000033
# 2016-12-16 03:28:00  1.978200  0.003217            1.978200         0.000050
# 2016-12-16 03:29:00  1.990950  0.003233            1.990950         0.000050
#
#                      Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  \
# 2016-12-16 03:25:00        0.085267        0.642417          0.041783
# 2016-12-16 03:26:00        0.104017        0.625033          0.041750
# 2016-12-16 03:27:00        0.422383        0.637733          0.042033
# 2016-12-16 03:28:00        0.495667        0.620367          0.042100
# 2016-12-16 03:29:00        0.494700        0.634133          0.042100
#
#                      Fridge [kW]  Wine cellar [kW]  Garage door [kW]  ...  \
# 2016-12-16 03:25:00     0.005267          0.008667          0.013483  ...
# 2016-12-16 03:26:00     0.005233          0.008433          0.013433  ...
# 2016-12-16 03:27:00     0.004983          0.008467          0.012933  ...
# 2016-12-16 03:28:00     0.005333          0.008233          0.012817  ...
# 2016-12-16 03:29:00     0.004917          0.008133          0.012833  ...
#
#                      temperature  humidity  visibility  apparentTemperature  \
# 2016-12-16 03:25:00        35.12      0.86        8.74                29.45
# 2016-12-16 03:26:00        35.12      0.86        8.74                29.45
# 2016-12-16 03:27:00        35.12      0.86        8.74                29.45
# 2016-12-16 03:28:00        35.12      0.86        8.74                29.45
# 2016-12-16 03:29:00        35.12      0.86        8.74                29.45
#
#                      pressure  windSpeed  windBearing  precipIntensity  \
# 2016-12-16 03:25:00   1011.49       6.72        186.0           0.0101
# 2016-12-16 03:26:00   1011.49       6.72        186.0           0.0101
# 2016-12-16 03:27:00   1011.49       6.72        186.0           0.0101
# 2016-12-16 03:28:00   1011.49       6.72        186.0           0.0101
# 2016-12-16 03:29:00   1011.49       6.72        186.0           0.0101
#
#                      dewPoint  precipProbability
# 2016-12-16 03:25:00     31.27               0.51
# 2016-12-16 03:26:00     31.27               0.51
# 2016-12-16 03:27:00     31.27               0.51
# 2016-12-16 03:28:00     31.27               0.51
# 2016-12-16 03:29:00     31.27               0.51
#
# [5 rows x 28 columns]

# %%
my_data.columns = [col.replace(' [kW]', '') for col in my_data.columns]
my_data.columns
# Out:
# Index(['use', 'gen', 'House overall', 'Dishwasher', 'Furnace 1', 'Furnace 2',
#        'Home office', 'Fridge', 'Wine cellar', 'Garage door', 'Kitchen 12',
#        'Kitchen 14', 'Kitchen 38', 'Barn', 'Well', 'Microwave', 'Living room',
#        'Solar', 'temperature', 'humidity', 'visibility', 'apparentTemperature',
#        'pressure', 'windSpeed', 'windBearing', 'precipIntensity', 'dewPoint',
#        'precipProbability'],
#       dtype='object')

# %%
my_data['Furnace'] = my_data[['Furnace 1','Furnace 2']].sum(axis=1)
my_data['Kitchen'] = my_data[['Kitchen 12','Kitchen 14','Kitchen 38']].sum(axis=1)

#df['Result'] = df['Column A']/df['Column B']
my_data.columns
my_data.head(5)
# Out:
#                           use       gen  House overall  Dishwasher  Furnace 1  \
# 2016-01-01 05:00:00  0.932833  0.003483       0.932833    0.000033   0.020700
# 2016-01-01 05:01:00  0.934333  0.003467       0.934333    0.000000   0.020717
# 2016-01-01 05:02:00  0.931817  0.003467       0.931817    0.000017   0.020700
# 2016-01-01 05:03:00  1.022050  0.003483       1.022050    0.000017   0.106900
# 2016-01-01 05:04:00  1.139400  0.003467       1.139400    0.000133   0.236933
#
#                      Furnace 2  Home office    Fridge  Wine cellar  \
# 2016-01-01 05:00:00   0.061917     0.442633  0.124150     0.006983
# 2016-01-01 05:01:00   0.063817     0.444067  0.124000     0.006983
# 2016-01-01 05:02:00   0.062317     0.446067  0.123533     0.006983
# 2016-01-01 05:03:00   0.068517     0.446583  0.123133     0.006983
# 2016-01-01 05:04:00   0.063983     0.446533  0.122850     0.006850
#
#                      Garage door  ...  visibility  apparentTemperature  \
# 2016-01-01 05:00:00     0.013083  ...        10.0                29.26
# 2016-01-01 05:01:00     0.013117  ...        10.0                29.26
# 2016-01-01 05:02:00     0.013083  ...        10.0                29.26
# 2016-01-01 05:03:00     0.013000  ...        10.0                29.26
# 2016-01-01 05:04:00     0.012783  ...        10.0                29.26
#
#                      pressure  windSpeed  windBearing  precipIntensity  \
# 2016-01-01 05:00:00   1016.91       9.18        282.0              0.0
# 2016-01-01 05:01:00   1016.91       9.18        282.0              0.0
# 2016-01-01 05:02:00   1016.91       9.18        282.0              0.0
# 2016-01-01 05:03:00   1016.91       9.18        282.0              0.0
# 2016-01-01 05:04:00   1016.91       9.18        282.0              0.0
#
#                      dewPoint  precipProbability   Furnace   Kitchen
# 2016-01-01 05:00:00      24.4                0.0  0.082617  0.000567
# 2016-01-01 05:01:00      24.4                0.0  0.084533  0.000567
# 2016-01-01 05:02:00      24.4                0.0  0.083017  0.000617
# 2016-01-01 05:03:00      24.4                0.0  0.175417  0.000650
# 2016-01-01 05:04:00      24.4                0.0  0.300917  0.000783
#
# [5 rows x 30 columns]

# %%
my_data['EneEffi'] = my_data['gen']/my_data['use']

# %%
my_data.head(5)
# Out:
#                           use       gen  House overall  Dishwasher  Furnace 1  \
# 2016-01-01 05:00:00  0.932833  0.003483       0.932833    0.000033   0.020700
# 2016-01-01 05:01:00  0.934333  0.003467       0.934333    0.000000   0.020717
# 2016-01-01 05:02:00  0.931817  0.003467       0.931817    0.000017   0.020700
# 2016-01-01 05:03:00  1.022050  0.003483       1.022050    0.000017   0.106900
# 2016-01-01 05:04:00  1.139400  0.003467       1.139400    0.000133   0.236933
#
#                      Furnace 2  Home office    Fridge  Wine cellar  \
# 2016-01-01 05:00:00   0.061917     0.442633  0.124150     0.006983
# 2016-01-01 05:01:00   0.063817     0.444067  0.124000     0.006983
# 2016-01-01 05:02:00   0.062317     0.446067  0.123533     0.006983
# 2016-01-01 05:03:00   0.068517     0.446583  0.123133     0.006983
# 2016-01-01 05:04:00   0.063983     0.446533  0.122850     0.006850
#
#                      Garage door  ...  apparentTemperature  pressure  \
# 2016-01-01 05:00:00     0.013083  ...                29.26   1016.91
# 2016-01-01 05:01:00     0.013117  ...                29.26   1016.91
# 2016-01-01 05:02:00     0.013083  ...                29.26   1016.91
# 2016-01-01 05:03:00     0.013000  ...                29.26   1016.91
# 2016-01-01 05:04:00     0.012783  ...                29.26   1016.91
#
#                      windSpeed  windBearing  precipIntensity  dewPoint  \
# 2016-01-01 05:00:00       9.18        282.0              0.0      24.4
# 2016-01-01 05:01:00       9.18        282.0              0.0      24.4
# 2016-01-01 05:02:00       9.18        282.0              0.0      24.4
# 2016-01-01 05:03:00       9.18        282.0              0.0      24.4
# 2016-01-01 05:04:00       9.18        282.0              0.0      24.4
#
#                      precipProbability   Furnace   Kitchen   EneEffi
# 2016-01-01 05:00:00                0.0  0.082617  0.000567  0.003734
# 2016-01-01 05:01:00                0.0  0.084533  0.000567  0.003710
# 2016-01-01 05:02:00                0.0  0.083017  0.000617  0.003720
# 2016-01-01 05:03:00                0.0  0.175417  0.000650  0.003408
# 2016-01-01 05:04:00                0.0  0.300917  0.000783  0.003043
#
# [5 rows x 31 columns]

# %%
energy_data = my_data.filter(items=[ 'EneEffi', 'use', 'gen', 'House overall', 'Dishwasher',
                                     'Furnace', 'Home office', 'Fridge',
                                     'Wine cellar', 'Garage door', 'Kitchen',
                                     'Barn', 'Well ', 'Microwave', 'Living room'])
energy_data.head(10)
# Out:
#                       EneEffi       use       gen  House overall  Dishwasher  \
# 2016-01-01 05:00:00  0.003734  0.932833  0.003483       0.932833    0.000033
# 2016-01-01 05:01:00  0.003710  0.934333  0.003467       0.934333    0.000000
# 2016-01-01 05:02:00  0.003720  0.931817  0.003467       0.931817    0.000017
# 2016-01-01 05:03:00  0.003408  1.022050  0.003483       1.022050    0.000017
# 2016-01-01 05:04:00  0.003043  1.139400  0.003467       1.139400    0.000133
# 2016-01-01 05:05:00  0.002467  1.391867  0.003433       1.391867    0.000283
# 2016-01-01 05:06:00  0.002525  1.366217  0.003450       1.366217    0.000283
# 2016-01-01 05:07:00  0.002386  1.431900  0.003417       1.431900    0.000250
# 2016-01-01 05:08:00  0.002100  1.627300  0.003417       1.627300    0.000183
# 2016-01-01 05:09:00  0.001969  1.735383  0.003417       1.735383    0.000017
#
#                       Furnace  Home office    Fridge  Wine cellar  \
# 2016-01-01 05:00:00  0.082617     0.442633  0.124150     0.006983
# 2016-01-01 05:01:00  0.084533     0.444067  0.124000     0.006983
# 2016-01-01 05:02:00  0.083017     0.446067  0.123533     0.006983
# 2016-01-01 05:03:00  0.175417     0.446583  0.123133     0.006983
# 2016-01-01 05:04:00  0.300917     0.446533  0.122850     0.006850
# 2016-01-01 05:05:00  0.566917     0.447033  0.122300     0.006717
# 2016-01-01 05:06:00  0.563117     0.443267  0.122050     0.006733
# 2016-01-01 05:07:00  0.656500     0.444283  0.121800     0.006783
# 2016-01-01 05:08:00  0.813350     0.441467  0.121617     0.006950
# 2016-01-01 05:09:00  0.854050     0.438733  0.121633     0.007233
#
#                      Garage door   Kitchen      Barn  Microwave  Living room
# 2016-01-01 05:00:00     0.013083  0.000567  0.031350   0.004067     0.001517
# 2016-01-01 05:01:00     0.013117  0.000567  0.031500   0.004067     0.001650
# 2016-01-01 05:02:00     0.013083  0.000617  0.031517   0.004067     0.001650
# 2016-01-01 05:03:00     0.013000  0.000650  0.031500   0.004067     0.001617
# 2016-01-01 05:04:00     0.012783  0.000783  0.031500   0.004067     0.001583
# 2016-01-01 05:05:00     0.012433  0.001050  0.031450   0.004067     0.001583
# 2016-01-01 05:06:00     0.012417  0.001067  0.031550   0.004117     0.001533
# 2016-01-01 05:07:00     0.012550  0.000933  0.031733   0.004200     0.001550
# 2016-01-01 05:08:00     0.012717  0.000783  0.031767   0.004200     0.001567
# 2016-01-01 05:09:00     0.013350  0.000417  0.031667   0.004200     0.001617

# %%
weather_data = my_data.filter(items=['Solar', 'temperature', 'humidity', 'visibility',
                               'apparentTemperature', 'pressure', 'windSpeed', 'cloudCover',
                               'windBearing', 'precipIntensity', 'dewPoint', 'precipProbability'])

weather_data.tail()
# Out:
#                         Solar  temperature  humidity  visibility  \
# 2016-12-16 03:25:00  0.003183        35.12      0.86        8.74
# 2016-12-16 03:26:00  0.003233        35.12      0.86        8.74
# 2016-12-16 03:27:00  0.003217        35.12      0.86        8.74
# 2016-12-16 03:28:00  0.003217        35.12      0.86        8.74
# 2016-12-16 03:29:00  0.003233        35.12      0.86        8.74
#
#                      apparentTemperature  pressure  windSpeed  windBearing  \
# 2016-12-16 03:25:00                29.45   1011.49       6.72        186.0
# 2016-12-16 03:26:00                29.45   1011.49       6.72        186.0
# 2016-12-16 03:27:00                29.45   1011.49       6.72        186.0
# 2016-12-16 03:28:00                29.45   1011.49       6.72        186.0
# 2016-12-16 03:29:00                29.45   1011.49       6.72        186.0
#
#                      precipIntensity  dewPoint  precipProbability
# 2016-12-16 03:25:00           0.0101     31.27               0.51
# 2016-12-16 03:26:00           0.0101     31.27               0.51
# 2016-12-16 03:27:00           0.0101     31.27               0.51
# 2016-12-16 03:28:00           0.0101     31.27               0.51
# 2016-12-16 03:29:00           0.0101     31.27               0.51

# %%
plt.figure();
weather_data.plot();

# %%
plt.figure();
energy_data.plot();

# %%
# Generate Data per (day) and (month) 
energy_per_day = energy_data.resample('D').sum()
energy_per_day.head()

weather_per_day = weather_data.resample('D').sum()
weather_per_day.head()
# Out:
#                  Solar  temperature  humidity  visibility  \
# 2016-01-01   18.026200     40727.34    720.28    11125.60
# 2016-01-02   76.051300     45637.30    835.28    14333.36
# 2016-01-03   74.081433     47914.02    883.58    14400.00
# 2016-01-04  108.525017     32108.72    861.98    14119.28
# 2016-01-05  148.107500     17208.20    770.82    14394.78
#
#             apparentTemperature    pressure  windSpeed  windBearing  \
# 2016-01-01             33989.34  1156803.96    8420.92     300606.0
# 2016-01-02             35226.44  1460895.76   11733.58     380922.0
# 2016-01-03             38548.42  1453861.98   10967.42     327054.0
# 2016-01-04             15936.88  1463662.42   16165.70     460508.0
# 2016-01-05              3973.98  1489091.46    9592.18     419634.0
#
#             precipIntensity  dewPoint  precipProbability
# 2016-01-01           0.1276  27849.26               2.32
# 2016-01-02           0.0000  26637.98               0.00
# 2016-01-03           0.0000  30604.26               0.00
# 2016-01-04           0.0000  14835.90               0.00
# 2016-01-05           0.0000  -3292.16               0.00

# %%
plt.figure(figsize=(40,10))
#energy_per_day.plot();
weather_per_day.plot();

# %%
weather_per_month = weather_data.resample('M').sum() # for energy we use sum to calculate overall consumption in period 
weather_per_month.head()
# Out:
#                   Solar  temperature  humidity  visibility  \
# 2016-01-31  2596.565467   1273505.14  27211.88   423867.34
# 2016-02-29  2704.221700   1272524.82  26287.66   370827.64
# 2016-03-31  3795.807367   1893779.82  27006.82   415287.06
# 2016-04-30  3893.534950   2009284.86  24343.16   407053.96
# 2016-05-31  3670.712050   2741102.92  28744.40   413311.66
#
#             apparentTemperature     pressure  windSpeed  windBearing  \
# 2016-01-31            972677.20  44993345.72  345774.82    9576194.0
# 2016-02-29           1019057.06  42408937.14  335978.38    9005914.0
# 2016-03-31           1725778.62  45325122.20  348506.48    8826994.0
# 2016-04-30           1906766.44  43968226.88  279707.68    7829250.0
# 2016-05-31           2718423.98  45292048.56  272747.04    8057126.0
#
#             precipIntensity    dewPoint  precipProbability
# 2016-01-31          52.4958   734720.96             935.54
# 2016-02-29         191.4000   773126.34            3619.78
# 2016-03-31         102.7296  1266782.82            3029.34
# 2016-04-30         106.1054  1266699.98            2660.28
# 2016-05-31         101.3780  2117725.96            2468.08

# %%
plt.figure(figsize=(40,10))
#energy_per_day.plot();
weather_per_month.plot();

# %%
energy_per_month = energy_data.resample('M').sum() # for energy we use sum to calculate overall consumption in period 
energy_per_month.head()
# Out:
#                   EneEffi           use          gen  House overall  \
# 2016-01-31   43399.078908  46256.153317  2596.565467   46256.153317
# 2016-02-29   26521.338062  41558.035267  2704.221700   41558.035267
# 2016-03-31  103256.120829  34026.880883  3795.807367   34026.880883
# 2016-04-30            NaN  29662.845900  3893.534950   29662.845900
# 2016-05-31   72564.506001  25550.843150  3670.712050   25550.843150
#
#              Dishwasher       Furnace  Home office       Fridge  Wine cellar  \
# 2016-01-31  1613.572299  20272.447383  4043.940117  2436.271883   840.762533
# 2016-02-29  1399.090831  19171.333067  2850.642583  2225.080050   832.488483
# 2016-03-31  1506.501997  13046.526433  3511.736400  2393.101050  1268.479517
# 2016-04-30  1443.403725   9393.876000  3173.250717  2454.983017  1548.467600
# 2016-05-31  1180.812253   5957.877471  2768.990462  2648.659933  1561.469854
#
#             Garage door     Kitchen         Barn   Microwave  Living room
# 2016-01-31   605.041667  462.033249  3314.010383  429.532350  1921.156633
# 2016-02-29   572.159733  411.821185  2817.221550  388.025434  1408.870900
# 2016-03-31   614.368167  403.409092  1791.915983  426.910884  1585.980033
# 2016-04-30   627.425083  311.436781  2626.763767  488.510350  1571.712033
# 2016-05-31   617.532683  297.327372  3321.740146  406.917284  1179.055583

# %%
ax = plt.gca()
energy_per_month.plot(kind='line',y='use',ax=ax)
energy_per_month.plot(kind='line',y='gen', color='blue', ax=ax)
energy_per_month.plot(kind='line',y='EneEffi', color='red', ax=ax)

plt.show()

# %%
plt.figure(figsize=(40,10))
energy_per_month.plot();

# %% [markdown]
# Energy Efficiency per month for every room filtered by devices

# %%
rooms_energy = energy_per_month.filter(items=[      # remove the devices consumption 
                                     'Home office',
                                     'Wine cellar', 'Kitchen',
                                     'Barn','Living room']) 
devices_energy = energy_per_month.filter(items=[ 'Dishwasher',
                                     'Furnace', 'Garage door', 'kitchen','Microwave'])
energy_efficiency =energy_per_month.filter(items=[ 'EneEffi', 'use', 'gen'])

all_rooms_consum = rooms_energy.sum()
all_devices_consum = devices_energy.sum()
all_energy_effi = energy_efficiency.sum()
print(all_rooms_consum)
print(all_devices_consum)
print(all_energy_effi)
# Out:
# Home office    40961.277962
# Wine cellar    21233.079320
# Kitchen         4932.186582
# Barn           29493.633696
# Living room    17794.476716
# dtype: float64
# Dishwasher      15806.409510
# Furnace        118917.457954
# Garage door      7124.847316
# Microwave        5534.440218
# dtype: float64
# EneEffi    801788.909645
# use        432839.740467
# gen         38412.764834
# dtype: float64

# %%
plot = all_rooms_consum .plot(kind = "pie", figsize = (5,5))
plot.set_title("Consumption for room")
# Out:
# Text(0.5, 1.0, 'Consumption for room')

# %%
plot = all_devices_consum .plot(kind = "pie", figsize = (5,5))
plot.set_title("Consumption for devices")
# Out:
# Text(0.5, 1.0, 'Consumption for devices')

# %%
plot = all_energy_effi.plot(kind = "bar", figsize = (5,5))
plot.set_title("energy efficiency")
# Out:
# Text(0.5, 1.0, 'energy efficiency')
